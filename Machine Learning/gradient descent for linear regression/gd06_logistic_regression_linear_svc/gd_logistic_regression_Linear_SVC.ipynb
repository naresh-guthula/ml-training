# %%
#Multivalue classification
import pandas
irisData = pandas.read_csv('iris.csv')

dataX = pandas.DataFrame({'slength': irisData.slength, 'swidth': irisData.swidth, 'plength': irisData.plength, 'pwidth': irisData.pwidth})
dataY = pandas.DataFrame({'flower': irisData.flower})

from sklearn.preprocessing import PolynomialFeatures
dataX = PolynomialFeatures(3).fit_transform(dataX)

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
dataX = scaler.fit_transform(dataX)

from sklearn.model_selection import train_test_split
trainX, testX, trainY, testY = train_test_split(dataX, dataY, test_size = 0.20, random_state = 11)

from sklearn.svm import LinearSVC
model = LinearSVC(C=1)
model.fit(trainX, trainY.values.ravel())

print ('Coefficients: ', model.coef_)
print ('Intercept: ', model.intercept_)
print('iterations ran :',model.n_iter_);
print ('R2: ', model.score (testX, testY))

yhat = model.predict(testX)
from sklearn.metrics import classification_report
print(classification_report(testY, yhat))

from sklearn.metrics import confusion_matrix
print(confusion_matrix(testY, yhat))
# Out:
# Coefficients:  [[ 0.         -0.08943488  0.20610552 -0.22422167 -0.24155397 -0.02788531
#    0.07984387 -0.11297244 -0.13096413  0.21799755 -0.18972406 -0.20880389
#   -0.05839164 -0.04187016 -0.0105325   0.02581648  0.05718773 -0.02390304
#   -0.03792422  0.15690978 -0.08389008 -0.10378085  0.01744078  0.0305871
#    0.05279173  0.22468251 -0.13375701 -0.16460688 -0.04516447 -0.0277256
#    0.00316179  0.07092607  0.09137938  0.11147345  0.12727782]
#  [ 0.          0.48403308 -0.49842763  0.56387931  0.36729347  0.22176739
#   -0.07460134  0.24170725  0.23085908 -0.3081203   0.57509     0.4753887
#   -0.23524541 -0.15008477 -0.33321269 -0.03492101 -0.08590179 -0.08693119
#    0.03803542 -0.1229969   0.20866836  0.29047651 -0.49670754 -0.30824568
#   -0.37990196 -0.14748972  0.66511406  0.63896207 -0.14051121  0.01060261
#   -0.09398544 -0.99103795 -0.71590086 -0.68635354 -0.78713269]
#  [ 0.         -0.46031299  0.13795534 -0.10547572 -0.04179836 -0.24322182
#   -0.08208258 -0.02729934 -0.05258015  0.01489485 -0.13301036 -0.16257216
#    0.26348428  0.18825408  0.36386757 -0.02481559  0.02030494  0.13105777
#    0.02535164 -0.03024551  0.01635594 -0.09691091  0.37800538  0.23722015
#    0.33707741 -0.06937819 -0.25375335 -0.34530669  0.21617136  0.08380138
#    0.19169529  0.64977165  0.45413856  0.48943801  0.64661909]]
# Intercept:  [-0.44956152 -0.8906296  -0.8912243 ]
# iterations ran : 514
# R2:  0.9666666666666667
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00         9
# Iris-versicolor       0.91      1.00      0.95        10
#  Iris-virginica       1.00      0.91      0.95        11
#
#       micro avg       0.97      0.97      0.97        30
#       macro avg       0.97      0.97      0.97        30
#    weighted avg       0.97      0.97      0.97        30
#
# [[ 9  0  0]
#  [ 0 10  0]
#  [ 0  1 10]]

# %%
myData2=pandas.read_csv('iris.csv')


dataX = pandas.DataFrame({'slength': myData2.slength,'swidth': myData2.swidth,'plength': myData2.plength,'pwidth': myData2.pwidth})
dataY = pandas.DataFrame({'flower': myData2.flower})


from sklearn.model_selection import train_test_split
trainX, testX, trainY, testY = train_test_split(dataX, dataY, \
                                               test_size = 0.30, random_state = 200)


from sklearn.preprocessing import StandardScaler

scaler= StandardScaler()
  
trainX=scaler.fit_transform(trainX)
    
testX = scaler.transform(testX)
# define the model

from sklearn.linear_model import SGDClassifier

sgd = SGDClassifier (max_iter=50000,tol=None)

# train the model
  
sgd.fit (trainX, trainY.values.ravel())

r2 = sgd.score(testX, testY.values.ravel())
print ('Coefficients: ', sgd.coef_)
print ('Intercept: ', sgd.intercept_)

print('iterations ran :',sgd.n_iter_);
print ('r2: \n', r2)

yhat = sgd.predict(testX)
from sklearn.metrics import classification_report
print(classification_report(testY, yhat))

from sklearn.metrics import confusion_matrix
print(confusion_matrix(testY, yhat))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:183: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If max_iter is set but tol is left unset, the default value for tol in 0.19 and 0.20 will be None (which is equivalent to -infinity, so it has no effect) but will change in 0.21 to 1e-3. Specify tol to silence this warning.
#   FutureWarning)
# Coefficients:  [[-0.36080614  0.48717243 -0.69566764 -0.64961324]
#  [ 0.3639637  -0.94551524  1.92657034 -2.27626506]
#  [-1.14597163 -1.46211888  7.81032533  6.48286979]]
# Intercept:  [-1.17332311 -0.78774118 -8.74902817]
# iterations ran : 50000
# r2:
#  1.0
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        18
# Iris-versicolor       1.00      1.00      1.00        16
#  Iris-virginica       1.00      1.00      1.00        11
#
#       micro avg       1.00      1.00      1.00        45
#       macro avg       1.00      1.00      1.00        45
#    weighted avg       1.00      1.00      1.00        45
#
# [[18  0  0]
#  [ 0 16  0]
#  [ 0  0 11]]

# %%
#Multivalue classification
import pandas
irisData = pandas.read_csv('iris.csv')

dataX = pandas.DataFrame({'slength': irisData.slength, 'swidth': irisData.swidth, 'plength': irisData.plength, 'pwidth': irisData.pwidth})
dataY = pandas.DataFrame({'flower': irisData.flower})

from sklearn.preprocessing import PolynomialFeatures
dataX = PolynomialFeatures(3).fit_transform(dataX)

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
dataX = scaler.fit_transform(dataX)

from sklearn.model_selection import train_test_split
trainX, testX, trainY, testY = train_test_split(dataX, dataY, test_size = 0.20, random_state = 11)

from sklearn.svm import SVC
model = SVC(C=4)
model.fit(trainX, trainY.values.ravel())

print ('Intercept: ', model.intercept_)
print ('R2: ', model.score (testX, testY))

yhat = model.predict(testX)
from sklearn.metrics import classification_report
print(classification_report(testY, yhat))

from sklearn.metrics import confusion_matrix
print(confusion_matrix(testY, yhat))
# Out:
# Intercept:  [-0.05536607 -0.34451557 -0.41683935]
# R2:  0.9333333333333333
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00         9
# Iris-versicolor       0.83      1.00      0.91        10
#  Iris-virginica       1.00      0.82      0.90        11
#
#       micro avg       0.93      0.93      0.93        30
#       macro avg       0.94      0.94      0.94        30
#    weighted avg       0.94      0.93      0.93        30
#
# [[ 9  0  0]
#  [ 0 10  0]
#  [ 0  2  9]]
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)

# %%
#Multiple models in loop
import pandas
irisData = pandas.read_csv('iris.csv')

dataX = pandas.DataFrame({'slength': irisData.slength, 'swidth': irisData.swidth, 'plength': irisData.plength, 'pwidth': irisData.pwidth})
dataY = pandas.DataFrame({'flower': irisData.flower})

from sklearn.preprocessing import PolynomialFeatures
dataX = PolynomialFeatures(3).fit_transform(dataX)

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
dataX = scaler.fit_transform(dataX)

from sklearn.model_selection import train_test_split
trainX, testX, trainY, testY = train_test_split(dataX, dataY, test_size = 0.20, random_state = 11)

from sklearn.svm import SVC
svcModel = SVC(C=4)
from sklearn.svm import LinearSVC
linearSVCModel = LinearSVC(C=1)

models= []
models.append(('SVC', svcModel))
models.append(('Linear SVC', linearSVCModel))
for modelName, model in models:
    model.fit(trainX, trainY.values.ravel())
    print('------------------------------------------')
    print('Result for: ', modelName)
    print('R2: ', model.score (testX, testY))


yhat = model.predict(testX)
from sklearn.metrics import classification_report
print(classification_report(testY, yhat))

from sklearn.metrics import confusion_matrix
print(confusion_matrix(testY, yhat))
# Out:
# ------------------------------------------
# Result for:  SVC
# R2:  0.9333333333333333
# ------------------------------------------
# Result for:  Linear SVC
# R2:  0.9666666666666667
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00         9
# Iris-versicolor       0.91      1.00      0.95        10
#  Iris-virginica       1.00      0.91      0.95        11
#
#       micro avg       0.97      0.97      0.97        30
#       macro avg       0.97      0.97      0.97        30
#    weighted avg       0.97      0.97      0.97        30
#
# [[ 9  0  0]
#  [ 0 10  0]
#  [ 0  1 10]]
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
