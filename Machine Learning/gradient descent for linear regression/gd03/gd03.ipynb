# %%
import pandas;
diabetesData = pandas.read_csv('Diabetes.csv')
diabetesData
# Out:
#      age  sex   bmi      bp   s1     s2    s3    s4      s5   s6    y
# 0     59    2  32.1  101.00  157   93.2  38.0  4.00  4.8598   87  151
# 1     48    1  21.6   87.00  183  103.2  70.0  3.00  3.8918   69   75
# 2     72    2  30.5   93.00  156   93.6  41.0  4.00  4.6728   85  141
# 3     24    1  25.3   84.00  198  131.4  40.0  5.00  4.8903   89  206
# 4     50    1  23.0  101.00  192  125.4  52.0  4.00  4.2905   80  135
# 5     23    1  22.6   89.00  139   64.8  61.0  2.00  4.1897   68   97
# 6     36    2  22.0   90.00  160   99.6  50.0  3.00  3.9512   82  138
# 7     66    2  26.2  114.00  255  185.0  56.0  4.55  4.2485   92   63
# 8     60    2  32.1   83.00  179  119.4  42.0  4.00  4.4773   94  110
# 9     29    1  30.0   85.00  180   93.4  43.0  4.00  5.3845   88  310
# 10    22    1  18.6   97.00  114   57.6  46.0  2.00  3.9512   83  101
# 11    56    2  28.0   85.00  184  144.8  32.0  6.00  3.5835   77   69
# ...

# %%
diabetesData.describe()
# Out:
#               age         sex         bmi          bp          s1          s2  \
# count  442.000000  442.000000  442.000000  442.000000  442.000000  442.000000
# mean    48.518100    1.468326   26.375792   94.647014  189.140271  115.439140
# std     13.109028    0.499561    4.418122   13.831283   34.608052   30.413081
# min     19.000000    1.000000   18.000000   62.000000   97.000000   41.600000
# 25%     38.250000    1.000000   23.200000   84.000000  164.250000   96.050000
# 50%     50.000000    1.000000   25.700000   93.000000  186.000000  113.000000
# 75%     59.000000    2.000000   29.275000  105.000000  209.750000  134.500000
# max     79.000000    2.000000   42.200000  133.000000  301.000000  242.400000
#
#                s3          s4          s5          s6           y
# count  442.000000  442.000000  442.000000  442.000000  442.000000
# mean    49.788462    4.070249    4.641411   91.260181  152.133484
# std     12.934202    1.290450    0.522391   11.496335   77.093005
# ...

# %%
from pandas.plotting import scatter_matrix
diabetesData.plot(kind='box', subplots=True, layout = (11,11), sharex = False, sharey = False)
scatter_matrix(diabetesData)

import matplotlib.pyplot as plt
plt.show()

# %%
dataX = pandas.DataFrame({'age': diabetesData.age, 'bmi': diabetesData.bmi \
                          , 'bp':diabetesData.bp, 's1': diabetesData.s1 \
                          , 's2':diabetesData.s2, 's3': diabetesData.s3 \
                          , 's4':diabetesData.s4, 's5': diabetesData.s5, 's6': diabetesData.s6
})

# %%
dataX
# Out:
#      age   bmi      bp   s1     s2    s3    s4      s5   s6
# 0     59  32.1  101.00  157   93.2  38.0  4.00  4.8598   87
# 1     48  21.6   87.00  183  103.2  70.0  3.00  3.8918   69
# 2     72  30.5   93.00  156   93.6  41.0  4.00  4.6728   85
# 3     24  25.3   84.00  198  131.4  40.0  5.00  4.8903   89
# 4     50  23.0  101.00  192  125.4  52.0  4.00  4.2905   80
# 5     23  22.6   89.00  139   64.8  61.0  2.00  4.1897   68
# 6     36  22.0   90.00  160   99.6  50.0  3.00  3.9512   82
# 7     66  26.2  114.00  255  185.0  56.0  4.55  4.2485   92
# 8     60  32.1   83.00  179  119.4  42.0  4.00  4.4773   94
# 9     29  30.0   85.00  180   93.4  43.0  4.00  5.3845   88
# 10    22  18.6   97.00  114   57.6  46.0  2.00  3.9512   83
# 11    56  28.0   85.00  184  144.8  32.0  6.00  3.5835   77
# 12    53  23.7   92.00  186  109.2  62.0  3.00  4.3041   81
# 13    50  26.2   97.00  186  105.4  49.0  4.00  5.0626   88
# 14    61  24.0   91.00  202  115.4  72.0  3.00  4.2905   73
# ...

# %%
dataY = pandas.DataFrame({'y': diabetesData.y})

# %%
from sklearn.model_selection import train_test_split
trainX, testX, trainY, testY = train_test_split(dataX, dataY, \
                                               test_size = 0.20, random_state = 11)

# %%
from sklearn.linear_model import SGDRegressor
model = SGDRegressor(shuffle = False, eta0 = 0.00003, max_iter = 1000, tol = 100, verbose=1)

# %%
model.fit(trainX, trainY.values.ravel())
# Out:
# -- Epoch 1
# Norm: 1.43, NNZs: 9, Bias: 0.003373, T: 353, Avg. loss: 3694.531800
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 1.88, NNZs: 9, Bias: 0.001976, T: 706, Avg. loss: 2622.945916
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 2.19, NNZs: 9, Bias: 0.000591, T: 1059, Avg. loss: 2397.806389
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 2.43, NNZs: 9, Bias: -0.000651, T: 1412, Avg. loss: 2274.422213
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 2.62, NNZs: 9, Bias: -0.001770, T: 1765, Avg. loss: 2192.997176
# Total training time: 0.00 seconds.
# -- Epoch 6
# Norm: 2.79, NNZs: 9, Bias: -0.002795, T: 2118, Avg. loss: 2133.734552
# Total training time: 0.00 seconds.
# -- Epoch 7
# Norm: 2.93, NNZs: 9, Bias: -0.003748, T: 2471, Avg. loss: 2087.914401
# Total training time: 0.00 seconds.
# -- Epoch 8
# Norm: 3.06, NNZs: 9, Bias: -0.004643, T: 2824, Avg. loss: 2051.027518
# Total training time: 0.00 seconds.
# -- Epoch 9
# ...

# %%
print ('Coefficients: ', model.coef_)
print ('Intercept: ', model.intercept_)

print('iterations ran :',model.n_iter_);

print ('R2: ', model.score (testX, testY))
# Out:
# Coefficients:  [-0.24209762  1.53537385  1.25002671  0.87164156 -0.93166344 -2.03942314
#   0.14862109  0.14556917  0.52399901]
# Intercept:  [-0.00549152]
# iterations ran : 9
# R2:  0.4721285429828152
